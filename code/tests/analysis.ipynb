# %%
try:
    import os, time
    import pandas as pd
    import sqlite3 as conn
    from matplotlib import pyplot as plt
except Exception as e:
    print(f'error while importing packages!\n{e}')

# %%
db_connect = conn.connect('../database/db/coronadb.db',timeout=10)
cursor = db_connect.cursor()
#check if connection established!
print(f'[🔥] Connecting to Database ... \n{db_connect}\
      \n[✔] Connected Successfully!')
# Out:
# [🔥] Connecting to Database ...
# ...
# [✔] Connected Successfully!

# %%
data = pd.read_sql_query("SELECT * FROM coviddata", db_connect)
data.head()
# Out:
#   countries_code region     countries      date  total_cases  new_cases  \
# 0            SAU   Asia  Saudi Arabia  02-03-20          1.0        1.0
# 1            SAU   Asia  Saudi Arabia  03-03-20          1.0        0.0
# 2            SAU   Asia  Saudi Arabia  04-03-20          1.0        0.0
# 3            SAU   Asia  Saudi Arabia  05-03-20          5.0        4.0
# 4            SAU   Asia  Saudi Arabia  06-03-20          5.0        0.0
#
#    total_deaths  new_deaths  new_tests  total_tests  positive_rate  \
# 0           0.0         0.0      160.0        160.0            0.0
# 1           0.0         0.0      240.0        400.0            0.0
# 2           0.0         0.0      298.0        698.0            0.0
# 3           0.0         0.0      487.0       1185.0            0.0
# 4           0.0         0.0     1024.0       2209.0            0.0
#
#    vaccinations  vaccinated  fully_vaccinated  new_vaccinations  population
# ...

# %%
data.columns
# Out:
# Index(['countries_code', 'region', 'countries', 'date', 'total_cases',
#        'new_cases', 'total_deaths', 'new_deaths', 'new_tests', 'total_tests',
#        'positive_rate', 'vaccinations', 'vaccinated', 'fully_vaccinated',
#        'new_vaccinations', 'population'],
#       dtype='object')

# %%
data.dtypes
# Out:
# countries_code       object
# region               object
# countries            object
# date                 object
# total_cases         float64
# new_cases           float64
# total_deaths        float64
# new_deaths          float64
# new_tests           float64
# total_tests         float64
# positive_rate       float64
# vaccinations        float64
# vaccinated          float64
# fully_vaccinated    float64
# new_vaccinations    float64
# population          float64
# dtype: object

# %%
data.groupby('new_vaccinations')['new_cases'].max().plot(figsize=(15,5), marker='o')
# Out:
# <AxesSubplot:xlabel='new_vaccinations'>

# %%
data.groupby('new_vaccinations')['total_cases'].max().plot(figsize=(15,5), marker='o')
# Out:
# <AxesSubplot:xlabel='new_vaccinations'>

# %%
data.groupby('new_vaccinations')['new_deaths'].max().plot(figsize=(15,5), marker='o')
# Out:
# <AxesSubplot:xlabel='new_vaccinations'>

# %%
data.groupby('new_vaccinations')['total_deaths'].max().plot(figsize=(15,5), marker='o')
# Out:
# <AxesSubplot:xlabel='new_vaccinations'>
