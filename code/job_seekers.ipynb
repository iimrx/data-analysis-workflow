# %%
import pandas as pd

# %%
df = pd.read_excel('../datasets/original/all_job_seekers2021.xlsx')
df.head()
# Out:
#           Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0  NES INDIVIDUAL ID     Gender     REGION       CITY        Age
# 1          171522499        ذكر        NaN        NaN         62
# 2          171979171        ذكر        NaN        NaN         43
# 3          162919038       أنثى        NaN        NaN         46
# 4          165410889        ذكر        NaN        NaN         66
#
#                 Unnamed: 5  Unnamed: 6 Unnamed: 7 Unnamed: 8       Unnamed: 9  \
# 0               EDU DEGREE       MAJOR        GPA   GPA FROM  INISTITUTE NAME
# 1  الماجستير أو ما يعادلها  إدارة عامة       3.50       4.00              NaN
# 2                      NaN         NaN        NaN        NaN              NaN
# 3                      NaN         NaN        NaN        NaN              NaN
# 4                      NaN         NaN        NaN        NaN              NaN
#
#      Unnamed: 10      Unnamed: 11  Unnamed: 12
# 0  INSERTED DATE  Graduation Date  record from
# ...

# %%
df.drop(df.index[[0]], inplace=True)
df.columns = ['id','gender','region','city','age','edu_degree','major','gpa','gpa_from','inistitute','inserted_date','grad_date','record_from']

# %%
df.head()
# Out:
#           id gender region city age               edu_degree       major  \
# 1  171522499    ذكر    NaN  NaN  62  الماجستير أو ما يعادلها  إدارة عامة
# 2  171979171    ذكر    NaN  NaN  43                      NaN         NaN
# 3  162919038   أنثى    NaN  NaN  46                      NaN         NaN
# 4  165410889    ذكر    NaN  NaN  66                      NaN         NaN
# 5  167174928    ذكر    NaN  NaN  42                      NaN         NaN
#
#     gpa gpa_from inistitute inserted_date grad_date record_from
# 1  3.50     4.00        NaN         44284     31158   old taqat
# 2   NaN      NaN        NaN         44289       NaN   old taqat
# 3   NaN      NaN        NaN         44214       NaN   old taqat
# 4   NaN      NaN        NaN         44234       NaN   old taqat
# 5   NaN      NaN        NaN         44249       NaN   old taqat

# %%
df.drop(['record_from','grad_date','inserted_date','gpa_from','gpa'], axis=1, inplace=True)
df.head(10)
# Out:
#            id gender  region    city age               edu_degree       major  \
# 1   171522499    ذكر     NaN     NaN  62  الماجستير أو ما يعادلها  إدارة عامة
# 2   171979171    ذكر     NaN     NaN  43                      NaN         NaN
# 3   162919038   أنثى     NaN     NaN  46                      NaN         NaN
# 4   165410889    ذكر     NaN     NaN  66                      NaN         NaN
# 5   167174928    ذكر     NaN     NaN  42                      NaN         NaN
# 6   162966568    ذكر     NaN     NaN  50                      NaN         NaN
# 7   162829976    ذكر  الرياض  الرياض  39                      NaN         NaN
# 8   173406324    ذكر     NaN     NaN  62                      NaN         NaN
# 9   169965689    ذكر     NaN     NaN  57                      NaN         NaN
# 10  170190626    ذكر     NaN     NaN  55                      NaN         NaN
#
#    inistitute
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# 5         NaN
# 6         NaN
# ...

# %%
df.describe()
# Out:
#                id  gender  region    city     age            edu_degree  \
# count      128215  121500    6606    6606  122730                 75011
# unique     128168       3      13     432      89                     9
# top     163039477     ذكر  الرياض  الرياض      20  ثانوية أو ما يعادلها
# freq            2   69744    3253     872   17696                 40317
#
#                                  major inistitute
# count                            74621      29798
# unique                              97        432
# top     لغات وترجمة - اللسانيات ودراسا       أخرى
# freq                             44618       8631

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 128215 entries, 1 to 128215
# Data columns (total 8 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   id          128215 non-null  object
#  1   gender      121500 non-null  object
#  2   region      6606 non-null    object
#  3   city        6606 non-null    object
#  4   age         122730 non-null  object
#  5   edu_degree  75011 non-null   object
#  6   major       74621 non-null   object
#  7   inistitute  29798 non-null   object
# dtypes: object(8)
# memory usage: 8.8+ MB

# %%
df.region.unique()
# Out:
# array([nan, 'الرياض', 'مكة المكرمة', 'المنطقة الشرقية', 'القصيم', 'تبوك',
#        'المدينة المنورة', 'حائل', 'عسير', 'الحدود الشمالية', 'الباحة',
#        'الجوف', 'جازان', 'نجران'], dtype=object)

# %%
df.city.unique()
# Out:
# array([nan, 'الرياض', 'جدة', 'المستجدة', 'الحائر (امارة الرياض)',
#        'الدمام', 'مكة المكرمة', 'الرس', 'الدارة (الدوادمي)', 'تبوك',
#        'الطائف', 'آل\xa0عامر', 'الخبر', 'المدينة المنورة', 'بقيق', 'حائل',
#        'القطيف', 'الدرعية (الدوادمي)', 'حفر\xa0الباطن', 'المبرز', 'سيهات',
#        'الظهران', 'البهيمة', 'شقراء', 'بريدة', 'خميس مشيط', 'عنيزة',
#        'ابها', 'الجبيلة', 'دخنة', 'الجبيل', 'وادي الدواسر', 'الرين',
#        'الخرج', 'رفحاء', 'صبحاء', 'تاروت', 'فرعة طريب', 'الجموم',
#        'العضيلية (الأحساء)', 'الغشامرة', 'سكاكا', 'صبيا', 'الأحسر',
#        'المزاحمية', 'الهفوف', 'العقيق', 'كياد', 'الزلفي', 'البحرة',
#        'بيشة (بيشة)', 'خميس البحر', 'بدر', 'عرعر', 'السليل',
#        'الحلوة (بني تميم)', 'صبياء', 'التمياط', 'السلامة (القنفذة)',
#        'الرهوة (بلجرشي)', 'المجمعة', 'باشوت', 'شرورة', 'صامطة', 'بلجرشي',
#        'الرويضة (المجمعة)', 'زبارة\xa0رشيد', 'الجعجاع',
#        'الفيصلية (المجمعة)', 'البارك (محايل)', 'شعب\xa0الذئب', 'املج',
# ...

# %%
df.edu_degree.unique()
# Out:
# array(['الماجستير أو ما يعادلها', nan, 'ثانوية أو ما يعادلها',
#        'البكالوريوس أو ما يعادلها', 'أقل من تعليم ابتدائي', 'متوسط',
#        'ابتدائي', 'دبلوم تقني أو ما يعادله', 'الدكتوراه أو ما يعادلها',
#        'تعليم تقني عالي أو ما يعادله'], dtype=object)

# %%
df.major.unique()
# Out:
# array(['إدارة عامة', nan, 'لغات وترجمة - اللسانيات ودراسا',
#        'الكيمياء الحيوية', 'الإعلام والإتصال', 'مالية', 'هندسة صناعية',
#        'محاسبة', 'إدارة أعمال', 'علوم الغذاء والتغذية', 'لغة عربية',
#        'هندسة ميكانيكية', 'علوم حاسب', 'تمريض', 'أحياء', 'علوم – معلمين',
#        'قانون', 'العلوم الإجتماعية – معلمين', 'الشريعة', 'علم الاجتماع',
#        'لغات وترجمة - انجليزي', 'الشبكات والإتصالات', 'هندسة كهربائية',
#        'نظم معلومات', 'تسويق', 'تربية خاصة', 'موارد بشرية',
#        'عمارة وتخطيط', 'تقنية المعلومات', 'رياضيات – معلمين', 'صيدلة',
#        'علوم سياسية', 'علم البحار', 'مكتبات و معلومات', 'الجغرافيا',
#        'هندسة الطيران', 'نظم معلومات إدارية', 'هندسة حاسب',
#        'ثقافة إسلامية – معلمين', 'علم الحديث', 'رسم وفنون', 'الرياضيات',
#        'اللغة الإنجليزية - معلمين', 'المختبرات', 'رياض الأطفال',
#        'إدارة فنادق', 'السكرتارية والأعمال المكتبية', 'الكيمياء',
#        'إقتصاد', 'طب بشري', 'الموسيقى والفنون المسرحية',
# ...

# %%
df.inistitute.unique()
# Out:
# array([nan, 'جامعة الملك سعود', 'جامعة الملك فيصل ',
#        'جامعة الملك عبد العزيز', 'جامعة الأعمال و التكنولوجيا', 'أخرى',
#        'جامعة أم القرى ', 'جامعة الإمام محمد بن سعود الإسلامية',
#        'جامعة الأميره نوره بنت عبد الرحمن', 'جامعة تبوك ', 'جامعة عفت',
#        'جامعة القصيم', 'التطوير الأهلية الليلية', 'جامعة الطائف ',
#        'جامعة الملك فهد للبترول و المعادن', 'جامعة الحدود الشمالية ',
#        'جامعة طيبة', 'جامعة حائل ', 'جامعة الدمام',
#        'مركز التدريب البيطري والانتاج الحيواني بالاحساء',
#        'الجامعة العربية المفتوحة', 'جامعة الفيصل ', 'جامعة الملك خالد',
#        'الجامعة السعودية الإلكترونية', 'رفحاء', 'الجامعة الإسلامية ',
#        'جامعة الجوف', 'جامعة بيشة', 'جامعة جازان ', 'جامعة دار العلوم',
#        'جامعة شقراء', 'مدارس التوحيد الاهلية',
#        'ادارة التدريب قاعدة الرياض الجوية', 'جامعة اليمامة ',
#        'ثانوية القريات الليلية', 'حمزة', 'جامعة جدة',
#        'جامعة الامير فهد بن سلطان ', 'جامعة الباحة',
# ...

# %%
df.fillna('لا يوجد', inplace=True)
df.head()
# Out:
#           id gender   region     city age               edu_degree  \
# 1  171522499    ذكر  لا يوجد  لا يوجد  62  الماجستير أو ما يعادلها
# 2  171979171    ذكر  لا يوجد  لا يوجد  43                  لا يوجد
# 3  162919038   أنثى  لا يوجد  لا يوجد  46                  لا يوجد
# 4  165410889    ذكر  لا يوجد  لا يوجد  66                  لا يوجد
# 5  167174928    ذكر  لا يوجد  لا يوجد  42                  لا يوجد
#
#         major inistitute
# 1  إدارة عامة    لا يوجد
# 2     لا يوجد    لا يوجد
# 3     لا يوجد    لا يوجد
# 4     لا يوجد    لا يوجد
# 5     لا يوجد    لا يوجد

# %%
len(df)
# Out:
# 128215

# %%
g_male = df.loc[df['gender']=='ذكر']
g_female = df.loc[(df['gender']=='أنثى') | (df['gender']=='انثى')].replace('انثى','أنثى')

# %%
df = pd.concat([g_male,g_female])

# %%
len(df)
# Out:
# 121500

# %%
un_wanted = df[(df['gender'] == 'لا يوجد') | (df['edu_degree'] == 'لا يوجد') | (df['inistitute'] == 'لا يوجد')].index
df.drop(un_wanted , inplace=True)

# %%
len(df)
# Out:
# 28415

# %%
male_grad_dbmd = df.loc[(df['age'] > 22) & (df['age'] <=30) & (df['inistitute'].str.startswith("جامعة"))]
female_grad_dbmd = df.loc[(df['age'] > 22) & (df['age'] <=30) & (df['inistitute'].str.startswith("جامعة"))]
